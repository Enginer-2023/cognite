# %% [markdown]
# <a href="https://colab.research.google.com/github/Enginer-2023/cognite/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements

# %%
# !pip install gradio
# Out:
# ...
#   Using cached fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 MB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.9/322.9 kB 31.5 MB/s eta 0:00:00
# ...
# Using cached fastapi-0.115.12-py3-none-any.whl (95 kB)
# ...
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 79.4 MB/s eta 0:00:00
# ...
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached starlette-0.46.2-py3-none-any.whl (72 kB)
# ...
